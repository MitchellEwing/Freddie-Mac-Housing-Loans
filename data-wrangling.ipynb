# %%
# download monthly performance data file, pair with loan sequence number, monthly performance
# table with have current loan delinquency status, which corresponds to the number of days the borrower
# is delinquent

# %%
# APPENDIX:

# sample_orig_YYYY.txt --> origination data
# sample_svcg_YYYY.txt --> monthly performance data

# superConformingFlag --> For mortagages that exceed conforming loan limits with origination dates on or after 10/1/2008
# and settlements on or after 1/1/2009.

# pre-HarpLoanSequenceNumber --> The Loan Sequence Number link that associates this HARP loan to the Pre-HARP Loan Sequence
# Number in the Single Family loan level dataset already being published on a quarterly basis.

# %%
# Import modules.
import pandas as pd

# %%
# Load data.
orig = orig_2017
perf = perf_2017

# %%
# View data.
print(orig.shape)
print(orig.columns)
orig.head()
# Out:
# (25000, 26)
# Index(['creditScore', 'firstPaymentDate', 'firstTimeHomebuyerFlag',
#        'maturityDate', 'msa', 'mortagageInsurancePercentage', 'numberOfUnits',
#        'occupancyStatus', 'cltvRatio', 'dtiRatio', 'upb', 'ltvRatio',
#        'interestRate', 'channel', 'ppmFlag', 'productType', 'propertyState',
#        'propertyType', 'postalCode', 'loanSequenceNumber', 'loanPurpose',
#        'originalLoanTerm', 'numberOfBorrowers', 'sellerName', 'servicerName',
#        'superConformingFlag'],
#       dtype='object')
#    creditScore  firstPaymentDate firstTimeHomebuyerFlag  maturityDate  \
# 0          794            201703                      9        204702
# 1          776            201703                      N        203202
# 2          795            201703                      9        203202
# 3          785            201705                      9        204704
# 4          758            201703                      9        203202
#
# ...

# %%
# View data.
print(perf.shape)
print(perf.columns)
perf.head()
# Out:
# (205484, 25)
# Index(['loanSequenceNumber', 'monthlyReportingPeriod', 'currentActualUpb',
#        'currentLoanDelinquencyStatus', 'loanAge', 'remainMthsToMaturity',
#        'repurchaseFlag', 'modificationFlag', 'zeroBalCode', 'zeroBalEffDate',
#        'currentIntRate', 'curDeferredUpb', 'ddlpi', 'miRecov',
#        'netSalesProceeds', 'nonMiRecov', 'expenses', 'legalCosts',
#        'maintPreservationCosts', 'taxesInsurance', 'miscExpenses',
#        'actualLossCalc', 'modificationCost', 'stepModificationFlag',
#        'deferredPaymentModification'],
#       dtype='object')
#   loanSequenceNumber  monthlyReportingPeriod  currentActualUpb  \
# 0       F117Q1000068                  201702          129000.0
# 1       F117Q1000068                  201703          129000.0
# 2       F117Q1000068                  201704          128000.0
# 3       F117Q1000068                  201705          128000.0
# 4       F117Q1000068                  201706          128000.0
#
# ...

# %%
# trim perf df by reporting period or loanSequenceNumber

# %%
# transpose df.columns to place side-by

# %%
# Viewing sample perf, less indexes were copied from txt file.
# Will use to this sample perf to match loanSequenceNumber

mlePerf = pd.read_csv('~/src/data/u3CapstoneData/perf-data/mle_perf2017.csv', sep='|',
                      header=None, low_memory=False)
mlePerf.columns = perf_2017_cols
mlePerf.head(10)
# Out:
#   loanSequenceNumber  monthlyReportingPeriod  currentActualUpb  \
# 0       F117Q1000068                  201702         129000.00
# 1       F117Q1000068                  201703         129000.00
# 2       F117Q1000068                  201704         128000.00
# 3       F117Q1000068                  201705         128000.00
# 4       F117Q1000068                  201706         128000.00
# 5       F117Q1000068                  201707         128000.00
# 6       F117Q1000068                  201708         128000.00
# 7       F117Q1000068                  201709         127112.25
# 8       F117Q1000068                  201710         126707.92
# 9       F117Q1000068                  201711         126363.75
#
#    currentLoanDelinquencyStatus  loanAge  remainMthsToMaturity repurchaseFlag  \
# 0                             0        0                   360            NaN
# 1                             0        1                   359            NaN
# ...

# %%
print(orig.shape)
orig.head(10)
# Out:
# (25000, 26)
#    creditScore  firstPaymentDate firstTimeHomebuyerFlag  maturityDate  \
# 0          794            201703                      9        204702
# 1          776            201703                      N        203202
# 2          795            201703                      9        203202
# 3          785            201705                      9        204704
# 4          758            201703                      9        203202
# 5          789            201703                      9        203202
# 6          807            201703                      9        203202
# 7          772            201704                      9        203203
# 8          663            201703                      9        203202
# 9          710            201703                      N        204702
#
#        msa  mortagageInsurancePercentage  numberOfUnits occupancyStatus  \
# 0  24260.0                             0              1               P
# ...

# %% [markdown]
# # Data

# %% [markdown]
# # 1999:

# %%
# Origination Data
orig_1999 = pd.read_csv('~/src/data/u3CapstoneData/origination-data/sample_orig_1999.txt',
                               sep='|', header=None)
orig_1999_cols = ['creditScore', 'firstPaymentDate', 'firstTimeHomebuyerFlag', 'maturityDate',
                   'msa', 'mortagageInsurancePercentage', 'numberOfUnits',
                   'occupancyStatus', 'cltvRatio', 'dtiRatio', 'upb',
                   'ltvRatio', 'interestRate', 'channel', 'ppmFlag', 'productType',
                   'propertyState', 'propertyType', 'postalCode', 'loanSequenceNumber',
                   'loanPurpose', 'originalLoanTerm', 'numberOfBorrowers', 'sellerName',
                   'servicerName', 'superConformingFlag'] # 'pre-HarpLoanSequenceNumber'
orig_1999.columns = orig_1999_cols
orig_1999.head()
# Out:
#    creditScore  firstPaymentDate firstTimeHomebuyerFlag  maturityDate  \
# 0          799            199903                      N        202901
# 1          635            200212                      N        202904
# 2          787            199905                      N        202904
# 3          726            199904                      N        202903
# 4          748            199905                      9        202904
#
#        msa  mortagageInsurancePercentage  numberOfUnits occupancyStatus  \
# 0  37620.0                             0              1               P
# 1  10420.0                             0              1               P
# 2  12060.0                           999              1               P
# 3  28140.0                             0              1               P
# 4  17140.0                           999              1               P
#
#    cltvRatio  dtiRatio         ...          propertyState  propertyType  \
# ...

# %%
# Monthly Performance Data
perf_1999 = pd.read_csv('~/src/data/u3CapstoneData/perf-data/sample_svcg_1999.txt',
                               sep='|', header=None, low_memory=False)
perf_1999_cols = ['loanSequenceNumber', 'monthlyReportingPeriod', 'currentActualUpb',
                 'currentLoanDelinquencyStatus', 'loanAge', 'remainMthsToMaturity', 'repurchaseFlag',
                 'modificationFlag', 'zeroBalCode', 'zeroBalEffDate', 'currentIntRate',
                 'curDeferredUpb', 'ddlpi', 'miRecov', 'netSalesProceeds', 'nonMiRecov',
                 'expenses', 'legalCosts', 'maintPreservationCosts', 'taxesInsurance',
                 'miscExpenses', 'actualLossCalc', 'modificationCost',
                 'stepModificationFlag', 'deferredPaymentModification']
perf_1999.columns = perf_1999_cols
perf_1999.head()
# Out:
#   loanSequenceNumber  monthlyReportingPeriod  currentActualUpb  \
# 0       F199Q1000012                  200208          42058.58
# 1       F199Q1000012                  200209          42011.81
# 2       F199Q1000012                  200210          41964.77
# 3       F199Q1000012                  200211          41917.46
# 4       F199Q1000012                  200212          41869.88
#
#   currentLoanDelinquencyStatus  loanAge  remainMthsToMaturity repurchaseFlag  \
# 0                            0       42                   317            NaN
# 1                            0       43                   316            NaN
# 2                            0       44                   315            NaN
# 3                            0       45                   314            NaN
# 4                            0       46                   313            NaN
#
#   modificationFlag  zeroBalCode  zeroBalEffDate             ...               \
# ...

# %% [markdown]
# # 2000:

# %%
# Origination Data
orig_2000 = pd.read_csv('~/src/data/u3CapstoneData/origination-data/sample_orig_2000.txt',
                               sep='|', header=None)
orig_2000_cols = ['creditScore', 'firstPaymentDate', 'firstTimeHomebuyerFlag', 'maturityDate',
                   'msa', 'mortagageInsurancePercentage', 'numberOfUnits',
                   'occupancyStatus', 'cltvRatio', 'dtiRatio', 'upb',
                   'ltvRatio', 'interestRate', 'channel', 'ppmFlag', 'productType',
                   'propertyState', 'propertyType', 'postalCode', 'loanSequenceNumber',
                   'loanPurpose', 'originalLoanTerm', 'numberOfBorrowers', 'sellerName',
                   'servicerName', 'superConformingFlag'] # 'pre-HarpLoanSequenceNumber'
orig_2000.columns = orig_2000_cols
orig_2000.head()
# Out:
#    creditScore  firstPaymentDate firstTimeHomebuyerFlag  maturityDate  \
# 0          750            200205                      N        203004
# 1          698            200210                      N        203003
# 2          708            200210                      N        203003
# 3          813            200302                      N        203004
# 4          734            200004                      N        203003
#
#        msa  mortagageInsurancePercentage  numberOfUnits occupancyStatus  \
# 0      NaN                             0              1               P
# 1  15940.0                             0              1               P
# 2  33340.0                            25              1               P
# 3  15380.0                             0              1               P
# 4  36740.0                            17              1               P
#
#    cltvRatio  dtiRatio         ...          propertyState  propertyType  \
# ...

# %%
# Monthly Performance Data
perf_2000 = pd.read_csv('~/src/data/u3CapstoneData/perf-data/sample_svcg_2000.txt',
                               sep='|', header=None, low_memory=False)
perf_2000_cols = ['loanSequenceNumber', 'monthlyReportingPeriod', 'currentActualUpb',
                 'currentLoanDelinquencyStatus', 'loanAge', 'remainMthsToMaturity', 'repurchaseFlag',
                 'modificationFlag', 'zeroBalCode', 'zeroBalEffDate', 'currentIntRate',
                 'curDeferredUpb', 'ddlpi', 'miRecov', 'netSalesProceeds', 'nonMiRecov',
                 'expenses', 'legalCosts', 'maintPreservationCosts', 'taxesInsurance',
                 'miscExpenses', 'actualLossCalc', 'modificationCost',
                 'stepModificationFlag', 'deferredPaymentModification']
perf_2000.columns = perf_2000_cols
perf_2000.head()
# Out:
#   loanSequenceNumber  monthlyReportingPeriod  currentActualUpb  \
# 0       F100Q1000004                  200204         187380.71
# 1       F100Q1000004                  200205         187380.71
# 2       F100Q1000004                  200206         187203.14
# 3       F100Q1000004                  200207         187024.52
# 4       F100Q1000004                  200208         186844.84
#
#   currentLoanDelinquencyStatus  loanAge  remainMthsToMaturity repurchaseFlag  \
# 0                            0       24                   336            NaN
# 1                            0       25                   335            NaN
# 2                            0       26                   334            NaN
# 3                            0       27                   333            NaN
# 4                            0       28                   332            NaN
#
#   modificationFlag  zeroBalCode  zeroBalEffDate             ...               \
# ...

# %% [markdown]
# # 2001:

# %%
# Origination Data
orig_2001 = pd.read_csv('~/src/data/u3CapstoneData/origination-data/sample_orig_2001.txt',
                               sep='|', header=None)
orig_2001_cols = ['creditScore', 'firstPaymentDate', 'firstTimeHomebuyerFlag', 'maturityDate',
                   'msa', 'mortagageInsurancePercentage', 'numberOfUnits',
                   'occupancyStatus', 'cltvRatio', 'dtiRatio', 'upb',
                   'ltvRatio', 'interestRate', 'channel', 'ppmFlag', 'productType',
                   'propertyState', 'propertyType', 'postalCode', 'loanSequenceNumber',
                   'loanPurpose', 'originalLoanTerm', 'numberOfBorrowers', 'sellerName',
                   'servicerName', 'superConformingFlag'] # 'pre-HarpLoanSequenceNumber'
orig_2001.columns = orig_2001_cols
orig_2001.head()
# Out:
#    creditScore  firstPaymentDate firstTimeHomebuyerFlag  maturityDate  \
# 0          783            200204                      N        203104
# 1          699            200105                      N        203104
# 2          715            200105                      N        203104
# 3          648            200104                      N        203103
# 4          720            200104                      N        203103
#
#        msa  mortagageInsurancePercentage  numberOfUnits occupancyStatus  \
# 0  31540.0                             0              1               P
# 1  12060.0                            25              1               P
# 2  41180.0                             0              1               P
# 3  47894.0                             0              1               P
# 4  14260.0                             0              1               P
#
#    cltvRatio  dtiRatio         ...          propertyState  propertyType  \
# ...

# %%
# Monthly Performance Data
perf_2001 = pd.read_csv('~/src/data/u3CapstoneData/perf-data/sample_svcg_2001.txt',
                               sep='|', header=None, low_memory=False)
perf_2001_cols = ['loanSequenceNumber', 'monthlyReportingPeriod', 'currentActualUpb',
                 'currentLoanDelinquencyStatus', 'loanAge', 'remainMthsToMaturity', 'repurchaseFlag',
                 'modificationFlag', 'zeroBalCode', 'zeroBalEffDate', 'currentIntRate',
                 'curDeferredUpb', 'ddlpi', 'miRecov', 'netSalesProceeds', 'nonMiRecov',
                 'expenses', 'legalCosts', 'maintPreservationCosts', 'taxesInsurance',
                 'miscExpenses', 'actualLossCalc', 'modificationCost',
                 'stepModificationFlag', 'deferredPaymentModification']
perf_2001.columns = perf_2001_cols
perf_2001.head()
# Out:
#   loanSequenceNumber  monthlyReportingPeriod  currentActualUpb  \
# 0       F101Q1000011                  200203          71966.12
# 1       F101Q1000011                  200204          71966.12
# 2       F101Q1000011                  200205          71230.94
# 3       F101Q1000011                  200206          71230.94
# 4       F101Q1000011                  200207          70860.07
#
#   currentLoanDelinquencyStatus  loanAge  remainMthsToMaturity repurchaseFlag  \
# 0                            0       11                   349            NaN
# 1                            0       12                   348            NaN
# 2                            0       13                   347            NaN
# 3                            0       14                   346            NaN
# 4                            0       15                   345            NaN
#
#   modificationFlag  zeroBalCode  zeroBalEffDate             ...               \
# ...

# %% [markdown]
# # 2002:

# %%
# Origination Data
orig_2002 = pd.read_csv('~/src/data/u3CapstoneData/origination-data/sample_orig_2002.txt',
                               sep='|', header=None)
orig_2002_cols = ['creditScore', 'firstPaymentDate', 'firstTimeHomebuyerFlag', 'maturityDate',
                   'msa', 'mortagageInsurancePercentage', 'numberOfUnits',
                   'occupancyStatus', 'cltvRatio', 'dtiRatio', 'upb',
                   'ltvRatio', 'interestRate', 'channel', 'ppmFlag', 'productType',
                   'propertyState', 'propertyType', 'postalCode', 'loanSequenceNumber',
                   'loanPurpose', 'originalLoanTerm', 'numberOfBorrowers', 'sellerName',
                   'servicerName', 'superConformingFlag'] # 'pre-HarpLoanSequenceNumber'
orig_2002.columns = orig_2002_cols
orig_2002.head()
# Out:
#    creditScore  firstPaymentDate firstTimeHomebuyerFlag  maturityDate  \
# 0          673            200204                      N        203203
# 1          668            200204                      N        203203
# 2          773            200204                      N        203203
# 3          683            200205                      N        203204
# 4          642            200204                      N        203203
#
#        msa  mortagageInsurancePercentage  numberOfUnits occupancyStatus  \
# 0      NaN                            25              1               P
# 1      NaN                             0              1               P
# 2  45780.0                             0              1               P
# 3  13460.0                             0              1               P
# 4  38900.0                            25              1               P
#
#    cltvRatio  dtiRatio         ...          propertyState  propertyType  \
# ...

# %%
# Monthly Performance Data
perf_2002 = pd.read_csv('~/src/data/u3CapstoneData/perf-data/sample_svcg_2002.txt',
                               sep='|', header=None, low_memory=False)
perf_2002_cols = ['loanSequenceNumber', 'monthlyReportingPeriod', 'currentActualUpb',
                 'currentLoanDelinquencyStatus', 'loanAge', 'remainMthsToMaturity', 'repurchaseFlag',
                 'modificationFlag', 'zeroBalCode', 'zeroBalEffDate', 'currentIntRate',
                 'curDeferredUpb', 'ddlpi', 'miRecov', 'netSalesProceeds', 'nonMiRecov',
                 'expenses', 'legalCosts', 'maintPreservationCosts', 'taxesInsurance',
                 'miscExpenses', 'actualLossCalc', 'modificationCost',
                 'stepModificationFlag', 'deferredPaymentModification']
perf_2002.columns = perf_2002_cols
perf_2002.head()
# Out:
#   loanSequenceNumber  monthlyReportingPeriod  currentActualUpb  \
# 0       F102Q1000047                  200203           39000.0
# 1       F102Q1000047                  200204           38000.0
# 2       F102Q1000047                  200205           38000.0
# 3       F102Q1000047                  200206           38000.0
# 4       F102Q1000047                  200207           38000.0
#
#   currentLoanDelinquencyStatus  loanAge  remainMthsToMaturity repurchaseFlag  \
# 0                            0        0                   360            NaN
# 1                            0        1                   359            NaN
# 2                            0        2                   358            NaN
# 3                            0        3                   357            NaN
# 4                            0        4                   356            NaN
#
#   modificationFlag  zeroBalCode  zeroBalEffDate             ...               \
# ...

# %% [markdown]
# # 2003:

# %%
# Origination Data
orig_2003 = pd.read_csv('~/src/data/u3CapstoneData/origination-data/sample_orig_2003.txt',
                               sep='|', header=None)
orig_2003_cols = ['creditScore', 'firstPaymentDate', 'firstTimeHomebuyerFlag', 'maturityDate',
                   'msa', 'mortagageInsurancePercentage', 'numberOfUnits',
                   'occupancyStatus', 'cltvRatio', 'dtiRatio', 'upb',
                   'ltvRatio', 'interestRate', 'channel', 'ppmFlag', 'productType',
                   'propertyState', 'propertyType', 'postalCode', 'loanSequenceNumber',
                   'loanPurpose', 'originalLoanTerm', 'numberOfBorrowers', 'sellerName',
                   'servicerName', 'superConformingFlag'] # 'pre-HarpLoanSequenceNumber'
orig_2003.columns = orig_2003_cols
orig_2003.head()
# Out:
#    creditScore  firstPaymentDate firstTimeHomebuyerFlag  maturityDate  \
# 0          813            200304                      N        203303
# 1          787            200303                      N        203302
# 2          700            200303                      N        203302
# 3          715            200303                      N        203302
# 4          731            200303                      N        203302
#
#        msa  mortagageInsurancePercentage  numberOfUnits occupancyStatus  \
# 0  16974.0                             0              1               P
# 1  44140.0                             0              1               P
# 2  33460.0                             0              1               P
# 3  44140.0                            30              1               P
# 4      NaN                             0              1               P
#
#    cltvRatio  dtiRatio         ...          propertyState  propertyType  \
# ...

# %%
# Monthly Performance Data
perf_2003 = pd.read_csv('~/src/data/u3CapstoneData/perf-data/sample_svcg_2003.txt',
                               sep='|', header=None, low_memory=False)
perf_2003_cols = ['loanSequenceNumber', 'monthlyReportingPeriod', 'currentActualUpb',
                 'currentLoanDelinquencyStatus', 'loanAge', 'remainMthsToMaturity', 'repurchaseFlag',
                 'modificationFlag', 'zeroBalCode', 'zeroBalEffDate', 'currentIntRate',
                 'curDeferredUpb', 'ddlpi', 'miRecov', 'netSalesProceeds', 'nonMiRecov',
                 'expenses', 'legalCosts', 'maintPreservationCosts', 'taxesInsurance',
                 'miscExpenses', 'actualLossCalc', 'modificationCost',
                 'stepModificationFlag', 'deferredPaymentModification']
perf_2003.columns = perf_2003_cols
perf_2003.head()
# Out:
#   loanSequenceNumber  monthlyReportingPeriod  currentActualUpb  \
# 0       F103Q1000013                  200303          110000.0
# 1       F103Q1000013                  200304          110000.0
# 2       F103Q1000013                  200305          110000.0
# 3       F103Q1000013                  200306          110000.0
# 4       F103Q1000013                  200307          110000.0
#
#   currentLoanDelinquencyStatus  loanAge  remainMthsToMaturity repurchaseFlag  \
# 0                            0        0                   360            NaN
# 1                            0        1                   359            NaN
# 2                            0        2                   358            NaN
# 3                            0        3                   357            NaN
# 4                            0        4                   356            NaN
#
#   modificationFlag  zeroBalCode  zeroBalEffDate             ...               \
# ...

# %% [markdown]
# # 2004:

# %%
# Origination Data
orig_2004 = pd.read_csv('~/src/data/u3CapstoneData/origination-data/sample_orig_2004.txt',
                               sep='|', header=None)
orig_2004_cols = ['creditScore', 'firstPaymentDate', 'firstTimeHomebuyerFlag', 'maturityDate',
                   'msa', 'mortagageInsurancePercentage', 'numberOfUnits',
                   'occupancyStatus', 'cltvRatio', 'dtiRatio', 'upb',
                   'ltvRatio', 'interestRate', 'channel', 'ppmFlag', 'productType',
                   'propertyState', 'propertyType', 'postalCode', 'loanSequenceNumber',
                   'loanPurpose', 'originalLoanTerm', 'numberOfBorrowers', 'sellerName',
                   'servicerName', 'superConformingFlag'] # 'pre-HarpLoanSequenceNumber'
orig_2004.columns = orig_2004_cols
orig_2004.head()
# Out:
#    creditScore  firstPaymentDate firstTimeHomebuyerFlag  maturityDate  \
# 0          758            200403                      N        203402
# 1          772            200403                      N        203402
# 2          771            200403                      N        203402
# 3          753            200403                      Y        203402
# 4          747            200403                      N        203402
#
#        msa  mortagageInsurancePercentage  numberOfUnits occupancyStatus  \
# 0      NaN                             0              1               P
# 1  17140.0                             0              1               P
# 2      NaN                             0              1               I
# 3      NaN                             0              1               P
# 4  30700.0                             0              2               I
#
#    cltvRatio  dtiRatio         ...          propertyState  propertyType  \
# ...

# %%
# Monthly Performance Data
perf_2004 = pd.read_csv('~/src/data/u3CapstoneData/perf-data/sample_svcg_2004.txt',
                               sep='|', header=None, low_memory=False)
perf_2004_cols = ['loanSequenceNumber', 'monthlyReportingPeriod', 'currentActualUpb',
                 'currentLoanDelinquencyStatus', 'loanAge', 'remainMthsToMaturity', 'repurchaseFlag',
                 'modificationFlag', 'zeroBalCode', 'zeroBalEffDate', 'currentIntRate',
                 'curDeferredUpb', 'ddlpi', 'miRecov', 'netSalesProceeds', 'nonMiRecov',
                 'expenses', 'legalCosts', 'maintPreservationCosts', 'taxesInsurance',
                 'miscExpenses', 'actualLossCalc', 'modificationCost',
                 'stepModificationFlag', 'deferredPaymentModification']
perf_2004.columns = perf_2004_cols
perf_2004.head()
# Out:
#   loanSequenceNumber  monthlyReportingPeriod  currentActualUpb  \
# 0       F104Q1000009                  200402          170000.0
# 1       F104Q1000009                  200403          169000.0
# 2       F104Q1000009                  200404          169000.0
# 3       F104Q1000009                  200405          169000.0
# 4       F104Q1000009                  200406          169000.0
#
#   currentLoanDelinquencyStatus  loanAge  remainMthsToMaturity repurchaseFlag  \
# 0                            0        0                   360            NaN
# 1                            0        1                   359            NaN
# 2                            0        2                   358            NaN
# 3                            0        3                   357            NaN
# 4                            0        4                   356            NaN
#
#   modificationFlag  zeroBalCode  zeroBalEffDate             ...               \
# ...

# %% [markdown]
# # 2005:

# %%
# Origination Data
orig_2005 = pd.read_csv('~/src/data/u3CapstoneData/origination-data/sample_orig_2005.txt',
                               sep='|', header=None)
orig_2005_cols = ['creditScore', 'firstPaymentDate', 'firstTimeHomebuyerFlag', 'maturityDate',
                   'msa', 'mortagageInsurancePercentage', 'numberOfUnits',
                   'occupancyStatus', 'cltvRatio', 'dtiRatio', 'upb',
                   'ltvRatio', 'interestRate', 'channel', 'ppmFlag', 'productType',
                   'propertyState', 'propertyType', 'postalCode', 'loanSequenceNumber',
                   'loanPurpose', 'originalLoanTerm', 'numberOfBorrowers', 'sellerName',
                   'servicerName', 'superConformingFlag'] # 'pre-HarpLoanSequenceNumber'
orig_2005.columns = orig_2005_cols
orig_2005.head()
# Out:
#    creditScore  firstPaymentDate firstTimeHomebuyerFlag  maturityDate  \
# 0          722            200504                      N        203503
# 1          759            200503                      N        203502
# 2          591            200504                      N        203503
# 3          792            200503                      N        203502
# 4          725            200503                      N        203502
#
#        msa  mortagageInsurancePercentage  numberOfUnits occupancyStatus  \
# 0      NaN                             0              1               P
# 1      NaN                             0              1               P
# 2  39100.0                             0              1               P
# 3  39100.0                             0              1               P
# 4  48864.0                             0              1               P
#
#    cltvRatio  dtiRatio         ...          propertyState  propertyType  \
# ...

# %%
# Monthly Performance Data
perf_2005 = pd.read_csv('~/src/data/u3CapstoneData/perf-data/sample_svcg_2005.txt',
                               sep='|', header=None, low_memory=False)
perf_2005_cols = ['loanSequenceNumber', 'monthlyReportingPeriod', 'currentActualUpb',
                 'currentLoanDelinquencyStatus', 'loanAge', 'remainMthsToMaturity', 'repurchaseFlag',
                 'modificationFlag', 'zeroBalCode', 'zeroBalEffDate', 'currentIntRate',
                 'curDeferredUpb', 'ddlpi', 'miRecov', 'netSalesProceeds', 'nonMiRecov',
                 'expenses', 'legalCosts', 'maintPreservationCosts', 'taxesInsurance',
                 'miscExpenses', 'actualLossCalc', 'modificationCost',
                 'stepModificationFlag', 'deferredPaymentModification']
perf_2005.columns = perf_2005_cols
perf_2005.head()
# Out:
#   loanSequenceNumber  monthlyReportingPeriod  currentActualUpb  \
# 0       F105Q1000064                  200503           62000.0
# 1       F105Q1000064                  200504           62000.0
# 2       F105Q1000064                  200505           62000.0
# 3       F105Q1000064                  200506           62000.0
# 4       F105Q1000064                  200507           62000.0
#
#   currentLoanDelinquencyStatus  loanAge  remainMthsToMaturity repurchaseFlag  \
# 0                            0        0                   360            NaN
# 1                            0        1                   359            NaN
# 2                            0        2                   358            NaN
# 3                            0        3                   357            NaN
# 4                            0        4                   356            NaN
#
#   modificationFlag  zeroBalCode  zeroBalEffDate             ...               \
# ...

# %% [markdown]
# # 2016:

# %%
# Origination Data
orig_2016 = pd.read_csv('~/src/data/u3CapstoneData/origination-data/sample_orig_2016.txt',
                               sep='|', header=None)
orig_2016_cols = ['creditScore', 'firstPaymentDate', 'firstTimeHomebuyerFlag', 'maturityDate',
                   'msa', 'mortagageInsurancePercentage', 'numberOfUnits',
                   'occupancyStatus', 'cltvRatio', 'dtiRatio', 'upb',
                   'ltvRatio', 'interestRate', 'channel', 'ppmFlag', 'productType',
                   'propertyState', 'propertyType', 'postalCode', 'loanSequenceNumber',
                   'loanPurpose', 'originalLoanTerm', 'numberOfBorrowers', 'sellerName',
                   'servicerName', 'superConformingFlag'] # 'pre-HarpLoanSequenceNumber'
orig_2016.columns = orig_2016_cols
orig_2016.head()
# Out:
#    creditScore  firstPaymentDate firstTimeHomebuyerFlag  maturityDate  \
# 0          742            201603                      Y        204602
# 1          776            201604                      9        204603
# 2          776            201603                      9        204602
# 3          719            201603                      N        204602
# 4          695            201603                      N        204602
#
#        msa  mortagageInsurancePercentage  numberOfUnits occupancyStatus  \
# 0      NaN                             0              1               P
# 1      NaN                             0              1               P
# 2  13780.0                             0              2               I
# 3  14260.0                            30              1               P
# 4      NaN                            30              1               P
#
#    cltvRatio  dtiRatio         ...          propertyState  propertyType  \
# ...

# %%
# Monthly Performance Data
perf_2016 = pd.read_csv('~/src/data/u3CapstoneData/perf-data/sample_svcg_2016.txt',
                               sep='|', header=None, low_memory=False)
perf_2016_cols = ['loanSequenceNumber', 'monthlyReportingPeriod', 'currentActualUpb',
                 'currentLoanDelinquencyStatus', 'loanAge', 'remainMthsToMaturity', 'repurchaseFlag',
                 'modificationFlag', 'zeroBalCode', 'zeroBalEffDate', 'currentIntRate',
                 'curDeferredUpb', 'ddlpi', 'miRecov', 'netSalesProceeds', 'nonMiRecov',
                 'expenses', 'legalCosts', 'maintPreservationCosts', 'taxesInsurance',
                 'miscExpenses', 'actualLossCalc', 'modificationCost',
                 'stepModificationFlag', 'deferredPaymentModification']
perf_2016.columns = perf_2016_cols
perf_2016.head()
# Out:
#   loanSequenceNumber  monthlyReportingPeriod  currentActualUpb  \
# 0       F116Q1000017                  201602           91000.0
# 1       F116Q1000017                  201603           90000.0
# 2       F116Q1000017                  201604           90000.0
# 3       F116Q1000017                  201605           90000.0
# 4       F116Q1000017                  201606           90000.0
#
#    currentLoanDelinquencyStatus  loanAge  remainMthsToMaturity repurchaseFlag  \
# 0                             0        0                   360            NaN
# 1                             0        1                   359            NaN
# 2                             0        2                   358            NaN
# 3                             0        3                   357            NaN
# 4                             0        4                   356            NaN
#
#   modificationFlag  zeroBalCode  zeroBalEffDate             ...               \
# ...

# %% [markdown]
# # 2017:

# %%
# Origination Data
orig_2017 = pd.read_csv('~/src/data/u3CapstoneData/origination-data/sample_orig_2017.txt',
                               sep='|', header=None)
orig_2017_cols = ['creditScore', 'firstPaymentDate', 'firstTimeHomebuyerFlag', 'maturityDate',
                   'msa', 'mortagageInsurancePercentage', 'numberOfUnits',
                   'occupancyStatus', 'cltvRatio', 'dtiRatio', 'upb',
                   'ltvRatio', 'interestRate', 'channel', 'ppmFlag', 'productType',
                   'propertyState', 'propertyType', 'postalCode', 'loanSequenceNumber',
                   'loanPurpose', 'originalLoanTerm', 'numberOfBorrowers', 'sellerName',
                   'servicerName', 'superConformingFlag'] # 'pre-HarpLoanSequenceNumber'
orig_2017.columns = orig_2017_cols
orig_2017.head()
# Out:
#    creditScore  firstPaymentDate firstTimeHomebuyerFlag  maturityDate  \
# 0          794            201703                      9        204702
# 1          776            201703                      N        203202
# 2          795            201703                      9        203202
# 3          785            201705                      9        204704
# 4          758            201703                      9        203202
#
#        msa  mortagageInsurancePercentage  numberOfUnits occupancyStatus  \
# 0  24260.0                             0              1               P
# 1      NaN                             0              1               P
# 2  49180.0                             0              1               P
# 3      NaN                            30              1               P
# 4  24260.0                             0              1               P
#
#    cltvRatio  dtiRatio         ...          propertyState  propertyType  \
# ...

# %%
# Monthly Performance Data
perf_2017 = pd.read_csv('~/src/data/u3CapstoneData/perf-data/sample_svcg_2017.txt',
                               sep='|', header=None, low_memory=False)
perf_2017_cols = ['loanSequenceNumber', 'monthlyReportingPeriod', 'currentActualUpb',
                 'currentLoanDelinquencyStatus', 'loanAge', 'remainMthsToMaturity', 'repurchaseFlag',
                 'modificationFlag', 'zeroBalCode', 'zeroBalEffDate', 'currentIntRate',
                 'curDeferredUpb', 'ddlpi', 'miRecov', 'netSalesProceeds', 'nonMiRecov',
                 'expenses', 'legalCosts', 'maintPreservationCosts', 'taxesInsurance',
                 'miscExpenses', 'actualLossCalc', 'modificationCost',
                 'stepModificationFlag', 'deferredPaymentModification']
perf_2017.columns = perf_2017_cols
perf_2017.head()
# Out:
#   loanSequenceNumber  monthlyReportingPeriod  currentActualUpb  \
# 0       F117Q1000068                  201702          129000.0
# 1       F117Q1000068                  201703          129000.0
# 2       F117Q1000068                  201704          128000.0
# 3       F117Q1000068                  201705          128000.0
# 4       F117Q1000068                  201706          128000.0
#
#    currentLoanDelinquencyStatus  loanAge  remainMthsToMaturity repurchaseFlag  \
# 0                             0        0                   360            NaN
# 1                             0        1                   359            NaN
# 2                             0        2                   358            NaN
# 3                             0        3                   357            NaN
# 4                             0        4                   356            NaN
#
#   modificationFlag  zeroBalCode  zeroBalEffDate             ...               \
# ...
